# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

esg_vocab = (
    ESG_KEYWORDS["environmental"]
    + ESG_KEYWORDS["social"]
    + ESG_KEYWORDS["governance"]
)

esg_vectorizer = TfidfVectorizer(
    vocabulary=esg_vocab,
    ngram_range=(1,2),
    lowercase=True
)

# %%
claims_df=pd.read_excel(
    "shell_claims_esg_deduped.xlsx",
)
claims_df
# Out:
#     company                                         claim_text  confidence
# 0     Shell  Sustainability at Achieving net-zero Sustainab...       0.926
# 1     Shell  Sustainability at Achieving net-zero Sustainab...       0.929
# 2     Shell  Powering lives oil and gas data Letter from th...       0.944
# 3     Shell  We achieved our second-best financial results ...       0.957
# 4     Shell  By year s end, we had achieved more than 60% o...       0.953
# ..      ...                                                ...         ...
# 388   Shell  Social investment A Estimated social investmen...       0.909
# 389   Shell  Social investment and contracting and procurem...       0.934
# 390   Shell          Total spend on goods and services million       0.950
# 391   Shell  Taxes paid and collected million Consolidated ...       0.936
# 392   Shell  Cash capital expenditure 2023 million Renewabl...       0.907
#
# [393 rows x 3 columns]
